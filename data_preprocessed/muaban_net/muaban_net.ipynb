# %%
# !pip install pandas
# !pip install geopy

# %%
import pandas as pd
import ssl
import certifi
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

ctx = ssl.create_default_context(cafile=certifi.where())

print("--- Step 1: Loading Data ---")
df = pd.read_csv('muaban_net.csv')

# Drop unnecessary fields and rename
fields_to_drop = [
    'area_unit', 'dimension_2', 'raw_n_bedrooms', 'raw_n_bathrooms', 
    'scraper', 'raw_price', 'balcony_direction', 'facing_direction'
]
df.drop(columns=[c for c in fields_to_drop if c in df.columns], inplace=True)
df.rename(columns={'legal_docs': 'legal'}, inplace=True)

# Convert float columns to integer
for col in ['n_bedrooms', 'n_bathrooms', 'n_floors']:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

print("--- Step 2: Geocoding (1 request per second) ---")
geolocator = Nominatim(user_agent="vn_real_estate_project", ssl_context=ctx, timeout=10)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1.1)

unique_addresses = df['address'].unique()
total_addr = len(unique_addresses)
address_coords_map = {}

print(f"Total unique addresses to process: {total_addr}")

for index, addr in enumerate(unique_addresses):
    # Print progress every 5 addresses
    if index % 5 == 0:
        print(f"Progress: {index}/{total_addr} addresses searched...")

    try:
        location = geocode(addr)
        if location:
            address_coords_map[addr] = (location.latitude, location.longitude)
        else:
            # Fallback: If street address fails, try geocoding just the District and City
            short_addr = ", ".join(addr.split(',')[-2:]) 
            location = geocode(short_addr)
            if location:
                address_coords_map[addr] = (location.latitude, location.longitude)
            else:
                address_coords_map[addr] = (None, None)
    except Exception:
        address_coords_map[addr] = (None, None)

# Map coordinates back to the original dataframe
df['latitude'] = df['address'].map(lambda x: address_coords_map[x][0])
df['longitude'] = df['address'].map(lambda x: address_coords_map[x][1])

print("--- Step 3: Saving Result ---")
df.to_csv('muaban_net_preprocessed.csv', index=False, encoding='utf-8-sig')
print("Done! Processed file: muaban_net_preprocessed.csv")
# Out:
# --- Step 1: Loading Data ---
# --- Step 2: Geocoding (1 request per second) ---
# Total unique addresses to process: 1620
# Progress: 0/1620 addresses searched...
# Progress: 5/1620 addresses searched...
# Progress: 10/1620 addresses searched...
# Progress: 15/1620 addresses searched...
# Progress: 20/1620 addresses searched...
# Progress: 25/1620 addresses searched...
# Progress: 30/1620 addresses searched...
# Progress: 35/1620 addresses searched...
# Progress: 40/1620 addresses searched...
# Progress: 45/1620 addresses searched...
# Progress: 50/1620 addresses searched...
# Progress: 55/1620 addresses searched...
# Progress: 60/1620 addresses searched...
# Progress: 65/1620 addresses searched...
# Progress: 70/1620 addresses searched...
# Progress: 75/1620 addresses searched...
# Progress: 80/1620 addresses searched...
# Progress: 85/1620 addresses searched...
# Progress: 90/1620 addresses searched...
# Progress: 95/1620 addresses searched...
# Progress: 100/1620 addresses searched...
# Progress: 105/1620 addresses searched...
# Progress: 110/1620 addresses searched...
# Progress: 115/1620 addresses searched...
# Progress: 120/1620 addresses searched...
# Progress: 125/1620 addresses searched...
# Progress: 130/1620 addresses searched...
# Progress: 135/1620 addresses searched...
# Progress: 140/1620 addresses searched...
# Progress: 145/1620 addresses searched...
# Progress: 150/1620 addresses searched...
# Progress: 155/1620 addresses searched...
# Progress: 160/1620 addresses searched...
# Progress: 165/1620 addresses searched...
# Progress: 170/1620 addresses searched...
# Progress: 175/1620 addresses searched...
# Progress: 180/1620 addresses searched...
# Progress: 185/1620 addresses searched...
# Progress: 190/1620 addresses searched...
# Progress: 195/1620 addresses searched...
# Progress: 200/1620 addresses searched...
# Progress: 205/1620 addresses searched...
# Progress: 210/1620 addresses searched...
# Progress: 215/1620 addresses searched...
# Progress: 220/1620 addresses searched...
# Progress: 225/1620 addresses searched...
# Progress: 230/1620 addresses searched...
# Progress: 235/1620 addresses searched...
# Progress: 240/1620 addresses searched...
# Progress: 245/1620 addresses searched...
# Progress: 250/1620 addresses searched...
# Progress: 255/1620 addresses searched...
# Progress: 260/1620 addresses searched...
# Progress: 265/1620 addresses searched...
# Progress: 270/1620 addresses searched...
# Progress: 275/1620 addresses searched...
# Progress: 280/1620 addresses searched...
# Progress: 285/1620 addresses searched...
# Progress: 290/1620 addresses searched...
# Progress: 295/1620 addresses searched...
# Progress: 300/1620 addresses searched...
# Progress: 305/1620 addresses searched...
# Progress: 310/1620 addresses searched...
# Progress: 315/1620 addresses searched...
# Progress: 320/1620 addresses searched...
# Progress: 325/1620 addresses searched...
# Progress: 330/1620 addresses searched...
# Progress: 335/1620 addresses searched...
# Progress: 340/1620 addresses searched...
# Progress: 345/1620 addresses searched...
# Progress: 350/1620 addresses searched...
# Progress: 355/1620 addresses searched...
# Progress: 360/1620 addresses searched...
# Progress: 365/1620 addresses searched...
# Progress: 370/1620 addresses searched...
# Progress: 375/1620 addresses searched...
# Progress: 380/1620 addresses searched...
# Progress: 385/1620 addresses searched...
# Progress: 390/1620 addresses searched...
# Progress: 395/1620 addresses searched...
# Progress: 400/1620 addresses searched...
# Progress: 405/1620 addresses searched...
# Progress: 410/1620 addresses searched...
# Progress: 415/1620 addresses searched...
# Progress: 420/1620 addresses searched...
# Progress: 425/1620 addresses searched...
# Progress: 430/1620 addresses searched...
# Progress: 435/1620 addresses searched...
# Progress: 440/1620 addresses searched...
# Progress: 445/1620 addresses searched...
# Progress: 450/1620 addresses searched...
# Progress: 455/1620 addresses searched...
# Progress: 460/1620 addresses searched...
# Progress: 465/1620 addresses searched...
# Progress: 470/1620 addresses searched...
# Progress: 475/1620 addresses searched...
# Progress: 480/1620 addresses searched...
# Progress: 485/1620 addresses searched...
# Progress: 490/1620 addresses searched...
# Progress: 495/1620 addresses searched...
# Progress: 500/1620 addresses searched...
# Progress: 505/1620 addresses searched...
# Progress: 510/1620 addresses searched...
# Progress: 515/1620 addresses searched...
# Progress: 520/1620 addresses searched...
# Progress: 525/1620 addresses searched...
# Progress: 530/1620 addresses searched...
# Progress: 535/1620 addresses searched...
# Progress: 540/1620 addresses searched...
# Progress: 545/1620 addresses searched...
# Progress: 550/1620 addresses searched...
# Progress: 555/1620 addresses searched...
# Progress: 560/1620 addresses searched...
# Progress: 565/1620 addresses searched...
# Progress: 570/1620 addresses searched...
# Progress: 575/1620 addresses searched...
# Progress: 580/1620 addresses searched...
# Progress: 585/1620 addresses searched...
# Progress: 590/1620 addresses searched...
# Progress: 595/1620 addresses searched...
# Progress: 600/1620 addresses searched...
# Progress: 605/1620 addresses searched...
# Progress: 610/1620 addresses searched...
# Progress: 615/1620 addresses searched...
# Progress: 620/1620 addresses searched...
# Progress: 625/1620 addresses searched...
# Progress: 630/1620 addresses searched...
# Progress: 635/1620 addresses searched...
# Progress: 640/1620 addresses searched...
# Progress: 645/1620 addresses searched...
# Progress: 650/1620 addresses searched...
# Progress: 655/1620 addresses searched...
# Progress: 660/1620 addresses searched...
# Progress: 665/1620 addresses searched...
# Progress: 670/1620 addresses searched...
# Progress: 675/1620 addresses searched...
# Progress: 680/1620 addresses searched...
# Progress: 685/1620 addresses searched...
# Progress: 690/1620 addresses searched...
# Progress: 695/1620 addresses searched...
# Progress: 700/1620 addresses searched...
# Progress: 705/1620 addresses searched...
# Progress: 710/1620 addresses searched...
# Progress: 715/1620 addresses searched...
# Progress: 720/1620 addresses searched...
# Progress: 725/1620 addresses searched...
# Progress: 730/1620 addresses searched...
# Progress: 735/1620 addresses searched...
# Progress: 740/1620 addresses searched...
# Progress: 745/1620 addresses searched...
# Progress: 750/1620 addresses searched...
# Progress: 755/1620 addresses searched...
# Progress: 760/1620 addresses searched...
# Progress: 765/1620 addresses searched...
# Progress: 770/1620 addresses searched...
# Progress: 775/1620 addresses searched...
# Progress: 780/1620 addresses searched...
# Progress: 785/1620 addresses searched...
# Progress: 790/1620 addresses searched...
# Progress: 795/1620 addresses searched...
# Progress: 800/1620 addresses searched...
# Progress: 805/1620 addresses searched...
# Progress: 810/1620 addresses searched...
# Progress: 815/1620 addresses searched...
# Progress: 820/1620 addresses searched...
# Progress: 825/1620 addresses searched...
# Progress: 830/1620 addresses searched...
# Progress: 835/1620 addresses searched...
# Progress: 840/1620 addresses searched...
# Progress: 845/1620 addresses searched...
# Progress: 850/1620 addresses searched...
# Progress: 855/1620 addresses searched...
# Progress: 860/1620 addresses searched...
# Progress: 865/1620 addresses searched...
# Progress: 870/1620 addresses searched...
# Progress: 875/1620 addresses searched...
# Progress: 880/1620 addresses searched...
# Progress: 885/1620 addresses searched...
# Progress: 890/1620 addresses searched...
# Progress: 895/1620 addresses searched...
# Progress: 900/1620 addresses searched...
# Progress: 905/1620 addresses searched...
# Progress: 910/1620 addresses searched...
# Progress: 915/1620 addresses searched...
# Progress: 920/1620 addresses searched...
# Progress: 925/1620 addresses searched...
# Progress: 930/1620 addresses searched...
# Progress: 935/1620 addresses searched...
# Progress: 940/1620 addresses searched...
# Progress: 945/1620 addresses searched...
# Progress: 950/1620 addresses searched...
# Progress: 955/1620 addresses searched...
# Progress: 960/1620 addresses searched...
# Progress: 965/1620 addresses searched...
# Progress: 970/1620 addresses searched...
# Progress: 975/1620 addresses searched...
# Progress: 980/1620 addresses searched...
# Progress: 985/1620 addresses searched...
# Progress: 990/1620 addresses searched...
# Progress: 995/1620 addresses searched...
# Progress: 1000/1620 addresses searched...
# Progress: 1005/1620 addresses searched...
# Progress: 1010/1620 addresses searched...
# Progress: 1015/1620 addresses searched...
# Progress: 1020/1620 addresses searched...
# Progress: 1025/1620 addresses searched...
# Progress: 1030/1620 addresses searched...
# Progress: 1035/1620 addresses searched...
# Progress: 1040/1620 addresses searched...
# Progress: 1045/1620 addresses searched...
# Progress: 1050/1620 addresses searched...
# Progress: 1055/1620 addresses searched...
# Progress: 1060/1620 addresses searched...
# Progress: 1065/1620 addresses searched...
# Progress: 1070/1620 addresses searched...
# Progress: 1075/1620 addresses searched...
# Progress: 1080/1620 addresses searched...
# Progress: 1085/1620 addresses searched...
# Progress: 1090/1620 addresses searched...
# Progress: 1095/1620 addresses searched...
# Progress: 1100/1620 addresses searched...
# Progress: 1105/1620 addresses searched...
# Progress: 1110/1620 addresses searched...
# Progress: 1115/1620 addresses searched...
# Progress: 1120/1620 addresses searched...
# Progress: 1125/1620 addresses searched...
# Progress: 1130/1620 addresses searched...
# Progress: 1135/1620 addresses searched...
# Progress: 1140/1620 addresses searched...
# Progress: 1145/1620 addresses searched...
# Progress: 1150/1620 addresses searched...
# Progress: 1155/1620 addresses searched...
# Progress: 1160/1620 addresses searched...
# Progress: 1165/1620 addresses searched...
# Progress: 1170/1620 addresses searched...
# Progress: 1175/1620 addresses searched...
# Progress: 1180/1620 addresses searched...
# Progress: 1185/1620 addresses searched...
# Progress: 1190/1620 addresses searched...
# Progress: 1195/1620 addresses searched...
# Progress: 1200/1620 addresses searched...
# Progress: 1205/1620 addresses searched...
# Progress: 1210/1620 addresses searched...
# Progress: 1215/1620 addresses searched...
# Progress: 1220/1620 addresses searched...
# Progress: 1225/1620 addresses searched...
# Progress: 1230/1620 addresses searched...
# Progress: 1235/1620 addresses searched...
# Progress: 1240/1620 addresses searched...
# Progress: 1245/1620 addresses searched...
# Progress: 1250/1620 addresses searched...
# Progress: 1255/1620 addresses searched...
# Progress: 1260/1620 addresses searched...
# Progress: 1265/1620 addresses searched...
# Progress: 1270/1620 addresses searched...
# Progress: 1275/1620 addresses searched...
# Progress: 1280/1620 addresses searched...
# Progress: 1285/1620 addresses searched...
# Progress: 1290/1620 addresses searched...
# Progress: 1295/1620 addresses searched...
# Progress: 1300/1620 addresses searched...
# Progress: 1305/1620 addresses searched...
# Progress: 1310/1620 addresses searched...
# Progress: 1315/1620 addresses searched...
# Progress: 1320/1620 addresses searched...
# Progress: 1325/1620 addresses searched...
# Progress: 1330/1620 addresses searched...
# Progress: 1335/1620 addresses searched...
# Progress: 1340/1620 addresses searched...
# Progress: 1345/1620 addresses searched...
# Progress: 1350/1620 addresses searched...
# Progress: 1355/1620 addresses searched...
# Progress: 1360/1620 addresses searched...
# Progress: 1365/1620 addresses searched...
# Progress: 1370/1620 addresses searched...
# Progress: 1375/1620 addresses searched...
# Progress: 1380/1620 addresses searched...
# Progress: 1385/1620 addresses searched...
# Progress: 1390/1620 addresses searched...
# Progress: 1395/1620 addresses searched...
# Progress: 1400/1620 addresses searched...
# Progress: 1405/1620 addresses searched...
# Progress: 1410/1620 addresses searched...
# Progress: 1415/1620 addresses searched...
# Progress: 1420/1620 addresses searched...
# Progress: 1425/1620 addresses searched...
# Progress: 1430/1620 addresses searched...
# Progress: 1435/1620 addresses searched...
# Progress: 1440/1620 addresses searched...
# Progress: 1445/1620 addresses searched...
# Progress: 1450/1620 addresses searched...
# Progress: 1455/1620 addresses searched...
# Progress: 1460/1620 addresses searched...
# Progress: 1465/1620 addresses searched...
# Progress: 1470/1620 addresses searched...
# Progress: 1475/1620 addresses searched...
# Progress: 1480/1620 addresses searched...
# Progress: 1485/1620 addresses searched...
# Progress: 1490/1620 addresses searched...
# Progress: 1495/1620 addresses searched...
# Progress: 1500/1620 addresses searched...
# Progress: 1505/1620 addresses searched...
# Progress: 1510/1620 addresses searched...
# Progress: 1515/1620 addresses searched...
# Progress: 1520/1620 addresses searched...
# Progress: 1525/1620 addresses searched...
# Progress: 1530/1620 addresses searched...
# Progress: 1535/1620 addresses searched...
# Progress: 1540/1620 addresses searched...
# Progress: 1545/1620 addresses searched...
# Progress: 1550/1620 addresses searched...
# Progress: 1555/1620 addresses searched...
# Progress: 1560/1620 addresses searched...
# Progress: 1565/1620 addresses searched...
# Progress: 1570/1620 addresses searched...
# Progress: 1575/1620 addresses searched...
# Progress: 1580/1620 addresses searched...
# Progress: 1585/1620 addresses searched...
# Progress: 1590/1620 addresses searched...
# Progress: 1595/1620 addresses searched...
# Progress: 1600/1620 addresses searched...
# Progress: 1605/1620 addresses searched...
# Progress: 1610/1620 addresses searched...
# Progress: 1615/1620 addresses searched...
# --- Step 3: Saving Result ---
# Done! Processed file: muaban_net_preprocessed.csv
