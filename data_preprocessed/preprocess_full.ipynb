# %%
import pandas as pd
import numpy as np
import re
import os

# %%
df = pd.read_csv('../data/preprocessed/full.csv')

# %% [markdown]
# ## Standardization

# %% [markdown]
# 1. **property_type**

# %%
import unicodedata

def normalize_text(text):
    if pd.isna(text):
        return np.nan
    text = str(text).lower().strip()
    text = unicodedata.normalize("NFKD", text)
    text = "".join(c for c in text if not unicodedata.combining(c))
    text = re.sub(r"\s+", " ", text)
    return text

# %%
print(f"Dataset shape before: {df.shape}")
print("Unique property_type (raw):")
print(df["property_type"].value_counts(dropna = False))

PROPERTY_TYPE_MAP = {
    "Nhà mặt phố": [
        "nhà mặt tiền", 
        "nhà mặt phố",
        "mặt tiền",
        "nhà riêng"
    ],
    "Nhà hẻm ngõ": [
        "nhà hẻm ngõ",
        "nhà hẻm, ngõ"
    ],
    "Biệt thự": [
        "biệt thự",
        "biệt thự, villa",
        "nhà biệt thự, liền kề"
    ],
    "Chung cư": [
        "căn hộ chung cư",
        "căn hộ chung cư mini"
    ],
    "Shophouse": [
        "shophouse, nhà phố thương mại"
    ],
    "Condotel": [
        "condotel"
    ]
}

def normalize_property_type(value):
    if pd.isna(value):
        return pd.NA

    value_norm = str(value).strip().lower()

    for standard_type, variants in PROPERTY_TYPE_MAP.items():
        for v in variants:
            if v.lower() in value_norm:
                return standard_type

    return "Khác"

df["property_type"] = df["property_type"].apply(normalize_property_type)

print("----------------------------------")
print("Unique property_type (normalized):")
print(df["property_type"].value_counts(dropna = False))
# Out:
# Dataset shape before: (13828, 15)
# Unique property_type (raw):
# property_type
# Nhà hẻm ngõ              2344
# Nhà riêng                2189
# Căn hộ chung cư          2159
# Nhà mặt tiền             2084
# Nhà mặt phố              2076
# Nhà biệt thự, liền kề    1990
# Mặt tiền                  512
# Biệt thự                  469
# Nhà hẻm, ngõ                4
# Biệt thự, Villa             1
# Name: count, dtype: int64
# ----------------------------------
# Unique property_type (normalized):
# property_type
# Nhà mặt phố    6861
# Biệt thự       2460
# Nhà hẻm ngõ    2348
# Chung cư       2159
# Name: count, dtype: int64

# %%
df = df[df["property_type"] != "Khác"].reset_index(drop = True)
print(df["property_type"].value_counts(dropna = False))
# Out:
# property_type
# Nhà mặt phố    6861
# Biệt thự       2460
# Nhà hẻm ngõ    2348
# Chung cư       2159
# Name: count, dtype: int64

# %% [markdown]
# 2. **legal**

# %%
def normalize_legal(val):
    if pd.isna(val):
        return "Không có"

    v = normalize_text(val)

    # GROUP 1: Sổ riêng / Chính chủ 
    if any(k in v for k in [
        "so do", "so hong", "so rieng", "chinh chu",
        "bia do", "shr", "tho cu", "hoan cong",
        "vinh vien", "lau dai"
    ]):
        return "Sổ riêng"

    # GROUP 2: Sổ chung . Đồng sở hữu 
    if any(k in v for k in [
        "so chung", "dong so huu", "su dung chung",
        "so do chung", "so hong chung", "dsh"
    ]):
        return "Sổ chung"

    # GROUP 3: Hợp đồng mua bán
    if any(k in v for k in [
        "hop dong", "hdmb", "dang cho so", "cho so",
        "chu dau tu", "50 nam", "70 nam", "tmdv"
    ]):
        return "Hợp đồng"

    # GROUP 4: Thoả thuận vi bằng
    if any(k in v for k in [
        "vi bang", "mua ban vi bang",
        "van ban thoa thuan", "vbtt"
    ]):
        return "Vi bằng"

    # GROUP 5: KHông rõ
    return "Không có"


df["legal"] = df["legal"].apply(normalize_legal)

print(df["legal"].value_counts(dropna = False))
# Out:
# legal
# Sổ riêng    7557
# Không có    6145
# Hợp đồng     119
# Sổ chung       4
# Vi bằng        3
# Name: count, dtype: int64

# %% [markdown]
# 3. **interior**

# %%
df["interior"].value_counts(dropna = False)
# Out:
# interior
# NaN                                                 8653
# Đầy đủ                                              2372
# Cơ bản                                              1125
# Không nội thất                                       485
# Đầy đủ.                                              346
#                                                     ...
# Bàn giao hoàn thiện cơ bản                             1
# Nội thất đầy đủ như điều hòa, tủ lạnh, giường...       1
# Chủ để lại toàn bộ nội thất.                           1
# Nội thất full nội thất cơ bản                          1
# Nội thất gần ful.                                      1
# Name: count, Length: 340, dtype: int64

# %%
if "interior" in df.columns:

    def normalize_interior(val):
        if pd.isna(val):
            return np.nan

        val = str(val).lower().strip()

        # không nội thất
        if re.search(r"không|trống|thô|chưa", val):
            return "Không nội thất"

        # cao cấp
        if re.search(r"cao cấp|luxury|sang|xịn|nhập khẩu", val):
            return "Nội thất cao cấp"

        # full nội thất
        if re.search(r"full|đầy đủ", val):
            return "Nội thất đầy đủ"

        # nội thất cơ bản
        if re.search(r"cơ bản|basic|có sẵn", val):
            return "Nội thất cơ bản"

        return np.nan

    df["interior"] = df["interior"].apply(normalize_interior)

# %%
df["interior"].value_counts(dropna = False)
# Out:
# interior
# NaN                 8755
# Nội thất đầy đủ     2962
# Nội thất cơ bản     1311
# Không nội thất       617
# Nội thất cao cấp     183
# Name: count, dtype: int64

# %% [markdown]
# ## Remove Outliers

# %%
print("Initial number of records: " + str(df.shape[0]))
# Out:
# Initial number of records: 13828

# %% [markdown]
# 1. **price**

# %%
df = df[df["price"] >= 0.5]

df = df[~(
    (df["property_type"] == "Nhà hẻm ngõ") & (df["property_type"] == "Nhà mặt phố") &
    (df["price"] > 500)
)]

print("Number of records: " + str(df.shape[0]))
# Out:
# Number of records: 13127

# %% [markdown]
# 2. **area**

# %%
df = df[(df["area"] >= 10) & (df["area"] <= 1500)]
print("Number of records: " + str(df.shape[0]))
# Out:
# Number of records: 12946

# %% [markdown]
# 3. **price_per_m2**

# %%
df["price_per_m2"] = (df["price"] * 1000) / df["area"]

df = df[
    (df["price_per_m2"] >= 5) &
    (df["price_per_m2"] <= 2000)
]
print("Number of records: " + str(df.shape[0]))
# Out:
# Number of records: 12785

# %% [markdown]
# ## Deal with Missing Data

# %% [markdown]
# 1. **longtitude** and **latitude**

# %%
print("Number of missing values on latitude: " + str(df['latitude'].isna().sum()))
print("Number of missing values on longitude: " + str(df['longitude'].isna().sum()))
# Out:
# Number of missing values on latitude: 260
# Number of missing values on longitude: 260

# %%
df["latitude"] = df["latitude"].fillna(
    df.groupby(["city_province", "district"])["latitude"].transform("mean")
)

df["longitude"] = df["longitude"].fillna(
    df.groupby(["city_province", "district"])["longitude"].transform("mean")
)

print("Number of missing values on latitude: " + str(df['latitude'].isna().sum()))
print("Number of missing values on longitude: " + str(df['longitude'].isna().sum()))
# Out:
# Number of missing values on latitude: 258
# Number of missing values on longitude: 258

# %%
# Fallback for remaning missing data
df["latitude"] = df["latitude"].fillna(
    df.groupby("city_province")["latitude"].transform("mean")
)

df["longitude"] = df["longitude"].fillna(
    df.groupby("city_province")["longitude"].transform("mean")
)

print("Number of missing values on latitude: " + str(df['latitude'].isna().sum()))
print("Number of missing values on longitude: " + str(df['longitude'].isna().sum()))
# Out:
# Number of missing values on latitude: 7
# Number of missing values on longitude: 7

# %% [markdown]
# 2. **n_floors**, **n_bedrooms** and **n_bathrooms**

# %%
print("Number of missing values on n_floors: " + str(df['n_floors'].isna().sum()))
print("Number of missing values on n_bedroomss: " + str(df['n_bedrooms'].isna().sum()))
print("Number of missing values on n_bathrooms: " + str(df['n_bathrooms'].isna().sum()))
# Out:
# Number of missing values on n_floors: 2817
# Number of missing values on n_bedroomss: 1768
# Number of missing values on n_bathrooms: 2063

# %%
# Rule-based filling
df.loc[
    (df["property_type"] == "Chung cư") & (df["n_floors"].isna()),
    "n_floors"
] = 1

df.loc[
    (df["property_type"] == "Nhà mặt phố") & (df["property_type"] == "Nhà hẻm ngõ") & (df["n_floors"].isna()),
    "n_floors"
] = 1

df.loc[
    (df["property_type"] == "Biệt thự") & (df["n_bedrooms"].isna()),
    "n_bedrooms"
] = 3

# %%
group_cols = ["property_type", "city_province", "district"]
num_cols = ["n_floors", "n_bedrooms", "n_bathrooms"]

for col in num_cols:
    df[col] = df[col].fillna(
        df.groupby(group_cols)[col].transform("median")
    )

print("Number of missing values on n_floors: " + str(df['n_floors'].isna().sum()))
print("Number of missing values on n_bedroomss: " + str(df['n_bedrooms'].isna().sum()))
print("Number of missing values on n_bathrooms: " + str(df['n_bathrooms'].isna().sum()))
# Out:
# Number of missing values on n_floors: 23
# Number of missing values on n_bedroomss: 12
# Number of missing values on n_bathrooms: 41

# %%
# Fallback to avoid that median = NaN
for col in ["n_floors", "n_bedrooms", "n_bathrooms"]:
    df[col] = df[col].fillna(df[col].median())

print("Number of missing values on n_floors: " + str(df['n_floors'].isna().sum()))
print("Number of missing values on n_bedroomss: " + str(df['n_bedrooms'].isna().sum()))
print("Number of missing values on n_bathrooms: " + str(df['n_bathrooms'].isna().sum()))
# Out:
# Number of missing values on n_floors: 0
# Number of missing values on n_bedroomss: 0
# Number of missing values on n_bathrooms: 0

# %% [markdown]
# 3. **price**

# %%
print("Number of missing values on price: " + str(df['price'].isna().sum()))
# Out:
# Number of missing values on price: 0

# %%
# def hierarchical_median_impute(
#     df, target_col, group_levels
# ):
#     """
#     df          : DataFrame
#     target_col  : cột cần fill (price_per_m2)
#     group_levels: list các list cột theo thứ tự ưu tiên
#     """
#     for group_cols in group_levels:
#         median_map = (
#             df
#             .groupby(group_cols)[target_col]
#             .median()
#         )

#         df[target_col] = df[target_col].fillna(
#             df[group_cols].apply(
#                 lambda x: median_map.get(tuple(x), np.nan),
#                 axis=1
#             )
#         )
#     return df

# %%
# group_levels = [
#     ["property_type", "district", "city_province"],
#     ["property_type", "district"],
#     ["property_type", "city_province"],
#     ["property_type"]
# ]

# df = hierarchical_median_impute(
#     df,
#     target_col = "price_per_m2",
#     group_levels = group_levels
# )

# %% [markdown]
# 4. **front_width**

# %%
print("Number of missing values on front_width: " + str(df['front_width'].isna().sum()))
# Out:
# Number of missing values on front_width: 4341

# %%
df["front_width"] = pd.to_numeric(df["front_width"], errors="coerce")

df.loc[df["front_width"] <= 0, "front_width"] = np.nan

# %%
df.loc[
    (df["property_type"] == "Chung cư") & (df["front_width"].isna()),
    "front_width"
] = 0

# %%
df["front_width"] = df["front_width"].fillna(
    df.groupby(
        ["city_province", "district", "property_type"]
    )["front_width"].transform("median")
)

# %%
df["front_width"] = df["front_width"].fillna(
    df.groupby(
        ["district", "property_type"]
    )["front_width"].transform("median")
)

# %%
df["front_width"] = df["front_width"].fillna(
    df.groupby("property_type")["front_width"].transform("median")
)

# %%
print("Number of missing values on front_width: " + str(df['front_width'].isna().sum()))
# Out:
# Number of missing values on front_width: 0

# %% [markdown]
# ## Feature Engineering

# %%
# New feature: price per m2
df["price_per_m2"] = df["price"] * 1000 / df["area"]

# %%
# Log-transform price and price_per_m2

df["log_price"] = np.log1p(df["price"])
df["log_price_per_m2"] = np.log1p(df["price_per_m2"])

# %%
# Flag for property type

df["is_apartment"] = df["property_type"].isin(["Chung cư"]).astype(int)
df["is_house_facing"] = df["property_type"].isin(["Nhà mặt phố"]).astype(int)
df["is_house_alley"] = df["property_type"].isin(["Nhà hẻm ngõ"]).astype(int)
df["is_villa"] = df["property_type"].isin(["Biệt thự"]).astype(int)

# %%
# Flag for having/not having interior
df["has_interior_info"] = df["interior"].notna().astype(int)
print(df["has_interior_info"].value_counts())

interior_map = {
    "Không nội thất": 0,
    "Nội thất cơ bản": 1,
    "Nội thất đầy đủ": 2,
    "Nội thất cao cấp": 3
}

df["interior_score"] = df["interior"].map(interior_map)
# Out:
# has_interior_info
# 0    7999
# 1    4786
# Name: count, dtype: int64

# %%
# Flag for legal status

legal_map = {
    "Sổ riêng": 4,
    "Sổ chung": 3,
    "Hợp đồng": 2,
    "Vi bằng": 1,
    "Không có": 0
}

df["legal_score"] = df["legal"].map(legal_map)

# %% [markdown]
# ## Remove Duplicates

# %%
import re
import unidecode

def normalize_text(s):
    if pd.isna(s):
        return None
    s = s.lower()
    s = unidecode.unidecode(s)          # bỏ dấu
    s = re.sub(r'[^a-z0-9\s]', ' ', s)  # bỏ ký tự đặc biệt
    s = re.sub(r'\s+', ' ', s).strip()
    return s

df["address_norm"] = df["address"].apply(normalize_text)

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %% [markdown]
# ## Save preprocessed data

# %%
df.head(5)
# Out:
#                                              address   area city_province  \
# 0  Dự án Masteri Thảo Điền, Đường Xa Lộ Hà Nội, P...   75.0   Hồ Chí Minh
# 1              Phúc Lợi, Phúc Lợi, Long Biên, Hà Nội   72.0        Hà Nội
# 2                        Phường 12, Đà Lạt, Lâm Đồng  102.3      Lâm Đồng
# 3  Đường Phạm Văn Chiêu, Phường 9, Gò Vấp, Hồ Chí...   60.9   Hồ Chí Minh
# 4  Đường Đồng Me, Phường Mễ Trì, Nam Từ Liêm, Hà Nội  148.0        Hà Nội
#
#       district  front_width         interior   latitude     legal   longitude  \
# 0       Quận 2         0.00  Nội thất đầy đủ  10.802441  Sổ riêng  106.741950
# 1    Long Biên         6.10  Nội thất đầy đủ  21.038832  Sổ riêng  105.934539
# 2       Đà Lạt         5.00  Nội thất đầy đủ  11.973893  Sổ riêng  108.484595
# 3       Gò Vấp         4.35  Nội thất cơ bản  10.849654  Sổ riêng  106.651222
# 4  Nam Từ Liêm         6.50  Nội thất đầy đủ  21.011918  Sổ riêng  105.776275
#
#    n_bathrooms  ...  log_price  log_price_per_m2  is_apartment  \
# 0          2.0  ...   2.163323          4.641181             1
# 1          6.0  ...   2.821379          5.395646             0
# 2          1.0  ...   2.140066          4.308296             0
# 3          2.0  ...   2.028148          4.694777             0
# 4         41.0  ...   4.094345          5.990586             0
#
#   is_house_facing is_house_alley  is_villa  has_interior_info  interior_score  \
# 0               0              0         0                  1             2.0
# 1               1              0         0                  1             2.0
# 2               1              0         0                  1             2.0
# 3               1              0         0                  1             1.0
# 4               1              0         0                  1             2.0
#
#    legal_score                                       address_norm
# 0            4  du an masteri thao dien duong xa lo ha noi phu...
# 1            4                 phuc loi phuc loi long bien ha noi
# 2            4                          phuong 12 da lat lam dong
# 3            4   duong pham van chieu phuong 9 go vap ho chi minh
# 4            4     duong dong me phuong me tri nam tu liem ha noi
#
# [5 rows x 26 columns]

# %%
print("Number of records: " + str(df.shape[0]))
# Out:
# Number of records: 9486

# %%
df.isna().sum()
# Out:
# address                 1
# area                    0
# city_province           1
# district                1
# front_width             0
# interior             5796
# latitude                6
# legal                   0
# longitude               6
# n_bathrooms             0
# n_bedrooms              0
# n_floors                0
# price                   0
# property_type           0
# source                  0
# price_per_m2            0
# log_price               0
# log_price_per_m2        0
# is_apartment            0
# is_house_facing         0
# is_house_alley          0
# is_villa                0
# has_interior_info       0
# interior_score       5796
# legal_score             0
# address_norm            1
# dtype: int64

# %%
if os.path.exists('../data/preprocessed/full_preprocessed.csv'):
    os.remove('../data/preprocessed/full_preprocessed.csv')
    print(f"Removed old file: ../data/preprocessed/full_preprocessed.csv")
else:
    print("No existing file to remove.")

os.makedirs(os.path.dirname('../data/preprocessed/full_preprocessed.csv'), exist_ok = True)

df.to_csv('../data/preprocessed/full_preprocessed.csv', index = False, encoding = "utf-8")
# Out:
# Removed old file: ../data/preprocessed/full_preprocessed.csv
